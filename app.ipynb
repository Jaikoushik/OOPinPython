# %%
class A:
    def __init__(self):
        self.a = 10
        self.b =20
        


    def hello(self):
        print("Hello World")

class B(A):
    def __init__(self):
        super().__init__()
        print("Hi bro")

a = B()
a.b+a.a
# Out:
# Hi bro
# 30
